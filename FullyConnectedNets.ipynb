# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cse493g1/assignments/assignment2/'
FOLDERNAME = 'cse493g1/assignments/assignment2/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cse493g1/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cse493g1/assignments/assignment2/cse493g1/datasets
# /content/drive/My Drive/cse493g1/assignments/assignment2

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cse493g1/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cse493g1/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from the previous notebook.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cse493g1.classifiers.fc_net import *
from cse493g1.data_utils import get_CIFAR10_data
from cse493g1.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cse493g1.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# patch to fix ipython dependency for python3.12
import subprocess
subprocess.run([
    "sed", "-i",
    "s/from imp import reload/from importlib import reload/",
    "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py"
], check=True)

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(493)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  0.0
# Running check with reg =  3.14
# Initial loss:  0.0

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 1e-1   # Experiment with this!
learning_rate = 1e-1  # Experiment with this!
model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=500,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)

# Sanity check output shape
dummy = model.loss(small_data["X_train"][:5])
print("scores shape:", dummy.shape)
# Must be (5, num_classes), e.g. (5, 10)

solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# scores shape: (5, 10)
# (Iteration 1 / 1000) loss: 270.106864
# (Epoch 0 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 500) train acc: 0.100000; val_acc: 0.077000
# (Epoch 3 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 4 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 5 / 500) train acc: 0.120000; val_acc: 0.105000
# (Iteration 11 / 1000) loss: 2.300314
# (Epoch 6 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 7 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 8 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 9 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 10 / 500) train acc: 0.120000; val_acc: 0.105000
# (Iteration 21 / 1000) loss: 2.284198
# (Epoch 11 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 12 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 13 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 14 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 15 / 500) train acc: 0.120000; val_acc: 0.105000
# (Iteration 31 / 1000) loss: 2.256531
# (Epoch 16 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 17 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 18 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 19 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 20 / 500) train acc: 0.120000; val_acc: 0.105000
# (Iteration 41 / 1000) loss: 2.255305
# (Epoch 21 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 22 / 500) train acc: 0.120000; val_acc: 0.105000
# (Epoch 23 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 24 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 25 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 51 / 1000) loss: 2.262043
# (Epoch 26 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 27 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 28 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 29 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 30 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 61 / 1000) loss: 2.245557
# (Epoch 31 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 32 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 33 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 34 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 35 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 71 / 1000) loss: 2.249000
# (Epoch 36 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 37 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 38 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 39 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 40 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 81 / 1000) loss: 2.279458
# (Epoch 41 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 42 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 43 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 44 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 45 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 91 / 1000) loss: 2.241792
# (Epoch 46 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 47 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 48 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 49 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 50 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 101 / 1000) loss: 2.255133
# (Epoch 51 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 52 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 53 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 54 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 55 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 111 / 1000) loss: 2.218639
# (Epoch 56 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 57 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 58 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 59 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 60 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 121 / 1000) loss: 2.173718
# (Epoch 61 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 62 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 63 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 64 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 65 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 131 / 1000) loss: 2.160592
# (Epoch 66 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 67 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 68 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 69 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 70 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 141 / 1000) loss: 2.223792
# (Epoch 71 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 72 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 73 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 74 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 75 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 151 / 1000) loss: 2.242675
# (Epoch 76 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 77 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 78 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 79 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 80 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 161 / 1000) loss: 2.268091
# (Epoch 81 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 82 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 83 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 84 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 85 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 171 / 1000) loss: 2.201098
# (Epoch 86 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 87 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 88 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 89 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 90 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 181 / 1000) loss: 2.181834
# (Epoch 91 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 92 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 93 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 94 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 95 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 191 / 1000) loss: 2.181025
# (Epoch 96 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 97 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 98 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 99 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 100 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 201 / 1000) loss: 2.307937
# (Epoch 101 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 102 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 103 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 104 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 105 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 211 / 1000) loss: 2.208754
# (Epoch 106 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 107 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 108 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 109 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 110 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 221 / 1000) loss: 2.161025
# (Epoch 111 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 112 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 113 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 114 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 115 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 231 / 1000) loss: 2.203423
# (Epoch 116 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 117 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 118 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 119 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 120 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 241 / 1000) loss: 2.101987
# (Epoch 121 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 122 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 123 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 124 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 125 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 251 / 1000) loss: 2.286382
# (Epoch 126 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 127 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 128 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 129 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 130 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 261 / 1000) loss: 2.224690
# (Epoch 131 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 132 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 133 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 134 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 135 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 271 / 1000) loss: 2.310198
# (Epoch 136 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 137 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 138 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 139 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 140 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 281 / 1000) loss: 2.098790
# (Epoch 141 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 142 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 143 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 144 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 145 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 291 / 1000) loss: 2.160785
# (Epoch 146 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 147 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 148 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 149 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 150 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 301 / 1000) loss: 2.334970
# (Epoch 151 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 152 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 153 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 154 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 155 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 311 / 1000) loss: 2.261579
# (Epoch 156 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 157 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 158 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 159 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 160 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 321 / 1000) loss: 2.171469
# (Epoch 161 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 162 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 163 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 164 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 165 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 331 / 1000) loss: 2.091194
# (Epoch 166 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 167 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 168 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 169 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 170 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 341 / 1000) loss: 2.221765
# (Epoch 171 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 172 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 173 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 174 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 175 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 351 / 1000) loss: 2.092635
# (Epoch 176 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 177 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 178 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 179 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 180 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 361 / 1000) loss: 2.244286
# (Epoch 181 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 182 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 183 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 184 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 185 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 371 / 1000) loss: 2.099510
# (Epoch 186 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 187 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 188 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 189 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 190 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 381 / 1000) loss: 2.247242
# (Epoch 191 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 192 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 193 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 194 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 195 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 391 / 1000) loss: 2.287934
# (Epoch 196 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 197 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 198 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 199 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 200 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 401 / 1000) loss: 2.284546
# (Epoch 201 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 202 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 203 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 204 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 205 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 411 / 1000) loss: 2.212888
# (Epoch 206 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 207 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 208 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 209 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 210 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 421 / 1000) loss: 2.206025
# (Epoch 211 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 212 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 213 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 214 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 215 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 431 / 1000) loss: 2.148075
# (Epoch 216 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 217 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 218 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 219 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 220 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 441 / 1000) loss: 2.106951
# (Epoch 221 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 222 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 223 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 224 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 225 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 451 / 1000) loss: 2.261629
# (Epoch 226 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 227 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 228 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 229 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 230 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 461 / 1000) loss: 2.162696
# (Epoch 231 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 232 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 233 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 234 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 235 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 471 / 1000) loss: 2.313524
# (Epoch 236 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 237 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 238 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 239 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 240 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 481 / 1000) loss: 2.227044
# (Epoch 241 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 242 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 243 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 244 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 245 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 491 / 1000) loss: 2.199517
# (Epoch 246 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 247 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 248 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 249 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 250 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 501 / 1000) loss: 2.210372
# (Epoch 251 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 252 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 253 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 254 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 255 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 511 / 1000) loss: 2.165010
# (Epoch 256 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 257 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 258 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 259 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 260 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 521 / 1000) loss: 2.108444
# (Epoch 261 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 262 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 263 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 264 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 265 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 531 / 1000) loss: 2.215123
# (Epoch 266 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 267 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 268 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 269 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 270 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 541 / 1000) loss: 2.254904
# (Epoch 271 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 272 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 273 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 274 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 275 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 551 / 1000) loss: 2.225945
# (Epoch 276 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 277 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 278 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 279 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 280 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 561 / 1000) loss: 2.297269
# (Epoch 281 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 282 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 283 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 284 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 285 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 571 / 1000) loss: 2.174166
# (Epoch 286 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 287 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 288 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 289 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 290 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 581 / 1000) loss: 2.429952
# (Epoch 291 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 292 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 293 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 294 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 295 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 591 / 1000) loss: 2.119596
# (Epoch 296 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 297 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 298 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 299 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 300 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 601 / 1000) loss: 2.230971
# (Epoch 301 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 302 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 303 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 304 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 305 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 611 / 1000) loss: 2.136987
# (Epoch 306 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 307 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 308 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 309 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 310 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 621 / 1000) loss: 2.294088
# (Epoch 311 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 312 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 313 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 314 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 315 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 631 / 1000) loss: 2.201792
# (Epoch 316 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 317 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 318 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 319 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 320 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 641 / 1000) loss: 2.174956
# (Epoch 321 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 322 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 323 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 324 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 325 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 651 / 1000) loss: 2.302809
# (Epoch 326 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 327 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 328 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 329 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 330 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 661 / 1000) loss: 2.186700
# (Epoch 331 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 332 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 333 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 334 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 335 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 671 / 1000) loss: 2.197735
# (Epoch 336 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 337 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 338 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 339 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 340 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 681 / 1000) loss: 2.130535
# (Epoch 341 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 342 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 343 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 344 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 345 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 691 / 1000) loss: 2.279176
# (Epoch 346 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 347 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 348 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 349 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 350 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 701 / 1000) loss: 2.172900
# (Epoch 351 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 352 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 353 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 354 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 355 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 711 / 1000) loss: 2.162911
# (Epoch 356 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 357 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 358 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 359 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 360 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 721 / 1000) loss: 2.177936
# (Epoch 361 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 362 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 363 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 364 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 365 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 731 / 1000) loss: 2.233645
# (Epoch 366 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 367 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 368 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 369 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 370 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 741 / 1000) loss: 2.064406
# (Epoch 371 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 372 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 373 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 374 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 375 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 751 / 1000) loss: 2.162858
# (Epoch 376 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 377 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 378 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 379 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 380 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 761 / 1000) loss: 2.237266
# (Epoch 381 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 382 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 383 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 384 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 385 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 771 / 1000) loss: 2.216401
# (Epoch 386 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 387 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 388 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 389 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 390 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 781 / 1000) loss: 2.140050
# (Epoch 391 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 392 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 393 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 394 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 395 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 791 / 1000) loss: 2.175754
# (Epoch 396 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 397 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 398 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 399 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 400 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 801 / 1000) loss: 2.152200
# (Epoch 401 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 402 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 403 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 404 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 405 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 811 / 1000) loss: 2.158909
# (Epoch 406 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 407 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 408 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 409 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 410 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 821 / 1000) loss: 2.191446
# (Epoch 411 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 412 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 413 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 414 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 415 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 831 / 1000) loss: 2.184765
# (Epoch 416 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 417 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 418 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 419 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 420 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 841 / 1000) loss: 2.179077
# (Epoch 421 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 422 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 423 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 424 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 425 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 851 / 1000) loss: 2.154031
# (Epoch 426 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 427 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 428 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 429 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 430 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 861 / 1000) loss: 2.248172
# (Epoch 431 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 432 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 433 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 434 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 435 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 871 / 1000) loss: 2.199816
# (Epoch 436 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 437 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 438 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 439 / 500) train acc: 0.160000; val_acc: 0.112000
# (Epoch 440 / 500) train acc: 0.160000; val_acc: 0.112000
# (Iteration 881 / 1000) loss: 2.499133
# (Epoch 441 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 442 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 443 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 444 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 445 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 891 / 1000) loss: 2.305372
# (Epoch 446 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 447 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 448 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 449 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 450 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 901 / 1000) loss: 2.116535
# (Epoch 451 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 452 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 453 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 454 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 455 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 911 / 1000) loss: 2.188410
# (Epoch 456 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 457 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 458 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 459 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 460 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 921 / 1000) loss: 2.287046
# (Epoch 461 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 462 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 463 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 464 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 465 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 931 / 1000) loss: 2.272158
# (Epoch 466 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 467 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 468 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 469 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 470 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 941 / 1000) loss: 2.311471
# (Epoch 471 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 472 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 473 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 474 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 475 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 951 / 1000) loss: 2.157208
# (Epoch 476 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 477 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 478 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 479 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 480 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 961 / 1000) loss: 2.099549
# (Epoch 481 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 482 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 483 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 484 / 500) train acc: 0.160000; val_acc: 0.079000
# (Epoch 485 / 500) train acc: 0.160000; val_acc: 0.079000
# (Iteration 971 / 1000) loss: 2.128794
# (Epoch 486 / 500) train acc: 0.160000; val_acc: 0.079000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3338/1444149936.py in <cell line: 0>()
#      32 # Must be (5, num_classes), e.g. (5, 10)
#      33
# ---> 34 solver.train()
#      35
#      36 plt.plot(solver.loss_history)
#
# /content/drive/MyDrive/cse493g1/assignments/assignment2/cse493g1/solver.py in train(self)
#     286                     self.X_train, self.y_train, num_samples=self.num_train_samples
#     287                 )
# --> 288                 val_acc = self.check_accuracy(
#     289                     self.X_val, self.y_val, num_samples=self.num_val_samples
#     290                 )
#
# /content/drive/MyDrive/cse493g1/assignments/assignment2/cse493g1/solver.py in check_accuracy(self, X, y, num_samples, batch_size)
#     245             start = i * batch_size
#     246             end = (i + 1) * batch_size
# --> 247             scores = self.model.loss(X[start:end])
#     248             y_pred.append(np.argmax(scores, axis=1))
#     249         y_pred = np.hstack(y_pred)
#
# /content/drive/MyDrive/cse493g1/assignments/assignment2/cse493g1/classifiers/fc_net.py in loss(self, X, y)
#     244         for i in range(self.num_layers - 1):
#     245           W, b = self.params[f'W{i+1}'], self.params[f'b{i+1}']
# --> 246           out, cache[i] = affine_relu_forward(out, W, b)
#     247
#     248         W, b = self.params[f'W{self.num_layers}'], self.params[f'b{self.num_layers}']
#
# /content/drive/MyDrive/cse493g1/assignments/assignment2/cse493g1/layer_utils.py in affine_relu_forward(x, w, b)
#      15     """
#      16     a, fc_cache = affine_forward(x, w, b)
# ---> 17     out, relu_cache = relu_forward(a)
#      18     cache = (fc_cache, relu_cache)
#      19     return out, cache
#
# /content/drive/MyDrive/cse493g1/assignments/assignment2/cse493g1/layers.py in relu_forward(x)
#      75
#      76
# ---> 77 def relu_forward(x):
#      78     """
#      79     Computes the forward pass for a layer of rectified linear units (ReLUs).
#
# KeyboardInterrupt:

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 2e-3  # Experiment with this!
weight_scale = 1e-5   # Experiment with this!
model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# $\color{red}{\text{SUBMIT THIS ON GRADESCOPE}}.$ **DO NOT WRITE YOUR ANSWER HERE.**
#
# [FILL THIS IN]

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section for more information.
#
# Open the file `cse493g1/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cse493g1.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cse493g1/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cse493g1.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))

# %%
# Test Adam implementation
from cse493g1.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
#
# $\color{red}{\text{SUBMIT THIS ON GRADESCOPE}}.$ **DO NOT WRITE YOUR ANSWER HERE.**

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
